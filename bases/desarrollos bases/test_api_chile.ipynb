# %%
import requests
import os
import pymysql
import time
import json
import datetime
from datetime import timedelta
import sys


# Configuración API
URL = "https://cramer.buk.cl/api/v1/chile/employees"
TOKEN = "Xegy8dVsa1H8SFfojJcwYtDL"

# Configuración BD - windows
DB_HOST = "192.168.245.33"
DB_USER = "compensaciones_rrhh"
DB_PASSWORD = "_Cramercomp2025_"
DB_NAME = "rrhh_app"

# %%
def obtener_todos_los_empleados_filtrados():
    """Sincroniza empleados y genera alertas (ejecución programada por Windows)."""
    headers = {"auth_token": TOKEN}
    empleados_filtrados = []
    url_actual = URL
    pagina_actual = 1
    
    print("obtención de los datos")
    
    while url_actual and pagina_actual <= 1:  
        print(f"Obteniendo página {pagina_actual}...")
        
        try:
            respuesta = requests.get(url_actual, headers=headers)
            respuesta.raise_for_status()
            
            respuesta_api = respuesta.json()
            empleados_pagina = respuesta_api['data']
            pagination_info = respuesta_api['pagination']
            
            # Filtrar cada empleado de esta página
            for empleado_completo in empleados_pagina:
                empleado_filtrado = {
                #información Personal
                "person_id": empleado_completo.get("person_id"),
                "id": empleado_completo.get("id"),
                "full_name": empleado_completo.get("full_name"),
                "rut": empleado_completo.get("rut"),
                "email": empleado_completo.get("email"),
                "personal_email": empleado_completo.get("personal_email"),
                "address": empleado_completo.get("address"),
                "street": empleado_completo.get("street"),
                "street_number": empleado_completo.get("street_number"),
                "city": empleado_completo.get("city"),
                "province": empleado_completo.get("province"),
                "district": empleado_completo.get("district"),
                "region": empleado_completo.get("region"),
                "phone": empleado_completo.get("phone"),
                "gender": empleado_completo.get("gender"),
                "birthday": empleado_completo.get("birthday"),
                "university": empleado_completo.get("university"),
                "degree": empleado_completo.get("degree"),
                "bank": empleado_completo.get("bank"),
                "account_type": empleado_completo.get("account_type"),
                "account_number": empleado_completo.get("account_number"),
                "nationality": empleado_completo.get("nationality"),
                "civil_status": empleado_completo.get("civil_status"),
                "health_company": empleado_completo.get("health_company"),
                "pension_regime": empleado_completo.get("pension_regime"),
                "pension_fund": empleado_completo.get("pension_fund"),
                "active_until": empleado_completo.get("active_until"),
                "afc": empleado_completo.get("afc"),
                "retired": empleado_completo.get("retired"),
                "retirement_regime": empleado_completo.get("retirement_regime"),
                #Información Laboral
                "active_since": empleado_completo.get("active_since"),
                "status": empleado_completo.get("status"),
                "start_date": empleado_completo.get("current_job", {}).get("start_date"),
                "end_date": empleado_completo.get("current_job", {}).get("end_date"),
                "termination_reason": empleado_completo.get("termination_reason"),
                "payment_method": empleado_completo.get("payment_method"),
                "id_boss": empleado_completo.get("current_job", {}).get("boss", {}).get("id"),
                "rut_boss": empleado_completo.get("current_job", {}).get("boss", {}).get("rut"),
                "base_wage": empleado_completo.get("current_job", {}).get("base_wage",),
                "contract_type": empleado_completo.get("current_job", {}).get("contract_type"),
                "contract_finishing_date_1": empleado_completo.get("current_job", {}).get("contract_finishing_date_1"),
                "contract_finishing_date_2": empleado_completo.get("current_job", {}).get("contract_finishing_date_2"),
                'name_role': empleado_completo.get("current_job", {}).get("role", {}).get("name"),
                'area_id': empleado_completo.get("current_job", {}).get("area_id"),
                "cost_center": empleado_completo.get("current_job", {}).get("cost_center"),
                "ctrlit_recinto": empleado_completo.get("current_job", {}).get("custom_attributes", {}).get("ctrlit_recinto"),
                }
                empleados_filtrados.append(empleado_filtrado)
            
            
            # Obtener la URL de la siguiente página
            url_actual = pagination_info.get('next')
            pagina_actual += 1
            
            # Pequeña pausa para no sobrecargar la API
            time.sleep(0.5)
            
        except requests.exceptions.RequestException as e:
            print(f"❌ Error en la petición: {e}")
            break
            
    print(f"Paginación completa!! empleados filtrados: {len(empleados_filtrados)}")
    print(json.dumps(empleados_filtrados, indent=4, ensure_ascii=False))

    return empleados_filtrados

# %%
if __name__ == "__main__":
    
    # Ejecutar SOLO UNA VEZ (para el Programador de Tareas)
    print("🔍 Ejecutando sincronización programada...")
    obtener_todos_los_empleados_filtrados()
# Out:
# 🔍 Ejecutando sincronización programada...
# obtención de los datos
# Obteniendo página 1...
# Paginación completa!! empleados filtrados: 25
# [
#     {
#         "person_id": 4232,
#         "id": 4232,
#         "full_name": "Cristian Transito Abarca Garrido",
#         "rut": "12.357.791-4",
#         "email": "abarcacristian0@gmail.com",
#         "personal_email": "abarcacristian0@gmail.com",
#         "address": "Pasaje Boston 1180",
#         "street": "",
#         "street_number": "",
#         "city": "",
#         "province": null,
#         "district": "Maipú",
#         "region": "RM: Metropolitana de Santiago",
#         "phone": "991294377",
#         "gender": "M",
#         "birthday": "1973-02-27",
#         "university": null,
#         "degree": null,
#         "bank": "BCI",
#         "account_type": "Corriente",
#         "account_number": "53527844",
#         "nationality": "Chilena",
#         "civil_status": "Soltero",
#         "health_company": "consalud",
#         "pension_regime": "afp",
#         "pension_fund": "modelo",
#         "active_until": null,
#         "afc": "normal",
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2020-02-04",
#         "status": "activo",
#         "start_date": "2025-04-01",
#         "end_date": null,
#         "termination_reason": null,
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 4678,
#         "rut_boss": "11.524.484-1",
#         "base_wage": 730000,
#         "contract_type": "Indefinido",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "Operario",
#         "area_id": 450,
#         "cost_center": "6005",
#         "ctrlit_recinto": "Lucerna -Reloj control",
#         "tipo_de_jornada_laboral": null
#     },
#     {
#         "person_id": 4827,
#         "id": 4846,
#         "full_name": "Javiera Valentina Abarca Riveros",
#         "rut": "19.792.744-5",
#         "email": "javiera.abarca@hotmail.com",
#         "personal_email": "javiera.abarca@hotmail.com",
#         "address": "Central Nino Garcia 3132",
#         "street": "",
#         "street_number": "",
#         "city": "Santiago",
#         "province": null,
#         "district": "Pedro Aguirre Cerda",
#         "region": "RM: Metropolitana de Santiago",
#         "phone": "987841220",
#         "gender": "F",
#         "birthday": "1997-12-13",
#         "university": "Universidad de Santiago de Chile",
#         "degree": "Tecnóloga en Alimentos ",
#         "bank": "Banco Estado",
#         "account_type": "Corriente",
#         "account_number": "19792744",
#         "nationality": "Chilena",
#         "civil_status": "Soltero",
#         "health_company": "fonasa",
#         "pension_regime": "afp",
#         "pension_fund": "habitat",
#         "active_until": null,
#         "afc": "normal",
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2022-04-11",
#         "status": "activo",
#         "start_date": "2025-04-01",
#         "end_date": null,
#         "termination_reason": null,
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 4514,
#         "rut_boss": "18.567.094-5",
#         "base_wage": 780000,
#         "contract_type": "Indefinido",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "Asistente De Laboratorio",
#         "area_id": 421,
#         "cost_center": "2002",
#         "ctrlit_recinto": "Lucerna -Reloj control",
#         "tipo_de_jornada_laboral": null
#     },
#     {
#         "person_id": 4308,
#         "id": 4308,
#         "full_name": "Manuel Jesus Abarca Moreira",
#         "rut": "14.194.403-7",
#         "email": "lolo201025@hotmail.cl",
#         "personal_email": "lolo201025@hotmail.cl",
#         "address": "Av. Cerrillos 4308",
#         "street": null,
#         "street_number": null,
#         "city": null,
#         "province": null,
#         "district": "Pedro Aguirre Cerda",
#         "region": "RM: Metropolitana de Santiago",
#         "phone": "973010445",
#         "gender": "M",
#         "birthday": "1981-04-18",
#         "university": null,
#         "degree": null,
#         "bank": "Falabella",
#         "account_type": "Corriente",
#         "account_number": "10013576630",
#         "nationality": "Chilena",
#         "civil_status": "Casado",
#         "health_company": "fonasa",
#         "pension_regime": "afp",
#         "pension_fund": "modelo",
#         "active_until": null,
#         "afc": "normal",
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2019-10-09",
#         "status": "activo",
#         "start_date": "2025-04-01",
#         "end_date": null,
#         "termination_reason": null,
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 4625,
#         "rut_boss": "26.689.690-5",
#         "base_wage": 825000,
#         "contract_type": "Indefinido",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "Operario",
#         "area_id": 446,
#         "cost_center": "6003",
#         "ctrlit_recinto": "Lucerna -Reloj control",
#         "tipo_de_jornada_laboral": null
#     },
#     {
#         "person_id": 4318,
#         "id": 4318,
#         "full_name": "Javier Jose Abdala Melo",
#         "rut": "15.141.674-8",
#         "email": "javier.abdala@hotmail.com",
#         "personal_email": "javier.abdala@hotmail.com",
#         "address": "Obispo Donoso 11 Dpto. 04",
#         "street": null,
#         "street_number": null,
#         "city": null,
#         "province": null,
#         "district": "Providencia",
#         "region": "RM: Metropolitana de Santiago",
#         "phone": "979415658",
#         "gender": "M",
#         "birthday": "1988-10-10",
#         "university": null,
#         "degree": "Ingeniero de Ejecución en Informática",
#         "bank": "Santander",
#         "account_type": "Corriente",
#         "account_number": "69240097",
#         "nationality": "Chilena",
#         "civil_status": "Soltero",
#         "health_company": "colmena",
#         "pension_regime": "afp",
#         "pension_fund": "cuprum",
#         "active_until": "2023-08-31",
#         "afc": "normal",
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2021-06-01",
#         "status": "inactivo",
#         "start_date": "2023-01-01",
#         "end_date": "2023-08-31",
#         "termination_reason": "renuncia",
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 4267,
#         "rut_boss": "13.168.537-8",
#         "base_wage": 2300000,
#         "contract_type": "Indefinido",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "Desarrollador Software",
#         "area_id": 15,
#         "cost_center": "7101",
#         "ctrlit_recinto": "Trabajo a distancia",
#         "tipo_de_jornada_laboral": null
#     },
#     {
#         "person_id": 4590,
#         "id": 4590,
#         "full_name": "Boaze Acaau ",
#         "rut": "25.564.708-3",
#         "email": "acaauboaze@gmail.com",
#         "personal_email": "acaauboaze@gmail.com",
#         "address": "Los Beduinos 1117",
#         "street": null,
#         "street_number": null,
#         "city": "",
#         "province": null,
#         "district": "Maipú",
#         "region": "RM: Metropolitana de Santiago",
#         "phone": "993165686",
#         "gender": "M",
#         "birthday": "1983-02-11",
#         "university": null,
#         "degree": null,
#         "bank": "Banco Estado",
#         "account_type": "Corriente",
#         "account_number": "30770099371",
#         "nationality": "Haitiana",
#         "civil_status": "Casado",
#         "health_company": "fonasa",
#         "pension_regime": "afp",
#         "pension_fund": "planvital",
#         "active_until": "2022-11-17",
#         "afc": "normal",
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2020-09-21",
#         "status": "inactivo",
#         "start_date": "2022-10-01",
#         "end_date": "2022-11-17",
#         "termination_reason": "necesidades_empresa",
#         "payment_method": "No Generar Pago",
#         "id_boss": 4432,
#         "rut_boss": "17.150.512-7",
#         "base_wage": 531000,
#         "contract_type": "Indefinido",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "Operario",
#         "area_id": 43,
#         "cost_center": "6004",
#         "ctrlit_recinto": "lucerna",
#         "tipo_de_jornada_laboral": null
#     },
#     {
#         "person_id": 4426,
#         "id": 4426,
#         "full_name": "Carolina Constanza Acevedo Echeverria",
#         "rut": "17.028.271-k",
#         "email": "cacevedo@cramer.cl",
#         "personal_email": null,
#         "address": "avenida ecuador 5065 Dpto. 1709",
#         "street": null,
#         "street_number": null,
#         "city": null,
#         "province": null,
#         "district": "Estación Central",
#         "region": "RM: Metropolitana de Santiago",
#         "phone": null,
#         "gender": "F",
#         "birthday": "1989-01-26",
#         "university": null,
#         "degree": null,
#         "bank": "Santander",
#         "account_type": "Corriente",
#         "account_number": "64802577",
#         "nationality": "Chilena",
#         "civil_status": "Soltero",
#         "health_company": "consalud",
#         "pension_regime": "afp",
#         "pension_fund": "habitat",
#         "active_until": "2019-10-01",
#         "afc": "normal",
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2018-08-20",
#         "status": "inactivo",
#         "start_date": "2018-08-20",
#         "end_date": "2019-10-01",
#         "termination_reason": "renuncia",
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 4426,
#         "rut_boss": "17.028.271-k",
#         "base_wage": 900000,
#         "contract_type": "Indefinido",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "Analista Contable",
#         "area_id": 11,
#         "cost_center": "7002",
#         "ctrlit_recinto": "sinrecinto",
#         "tipo_de_jornada_laboral": null
#     },
#     {
#         "person_id": 4551,
#         "id": 4551,
#         "full_name": "Alexander Jacob Acosta Gomez",
#         "rut": "19.418.289-9",
#         "email": "aacosta@cramer.cl",
#         "personal_email": "alexander.acostaofi@gmail.com",
#         "address": "Bartolo Soto 3950 Dpto. 304",
#         "street": null,
#         "street_number": null,
#         "city": "",
#         "province": null,
#         "district": "San Miguel",
#         "region": "RM: Metropolitana de Santiago",
#         "phone": "931397647",
#         "gender": "M",
#         "birthday": "1996-11-11",
#         "university": null,
#         "degree": null,
#         "bank": "Santander",
#         "account_type": "Corriente",
#         "account_number": "73852757",
#         "nationality": "Chilena",
#         "civil_status": "Soltero",
#         "health_company": "fonasa",
#         "pension_regime": "afp",
#         "pension_fund": "modelo",
#         "active_until": "2022-02-14",
#         "afc": "normal",
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2020-01-20",
#         "status": "inactivo",
#         "start_date": "2020-01-20",
#         "end_date": "2022-02-14",
#         "termination_reason": "necesidades_empresa",
#         "payment_method": "No Generar Pago",
#         "id_boss": 4591,
#         "rut_boss": "25.607.565-2",
#         "base_wage": 464000,
#         "contract_type": "Indefinido",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "Asistente De Laboratorio",
#         "area_id": 76,
#         "cost_center": "2011",
#         "ctrlit_recinto": "lucerna",
#         "tipo_de_jornada_laboral": null
#     },
#     {
#         "person_id": 4542,
#         "id": 4542,
#         "full_name": "Victor Leonardo Acosta Alegria",
#         "rut": "9.252.524-4",
#         "email": "vacosta@cramer.cl",
#         "personal_email": "Victor.leonardo487@gmail.com",
#         "address": "JOAQUIN PALACIO V.PTE ALT 487",
#         "street": "",
#         "street_number": "",
#         "city": "",
#         "province": null,
#         "district": "Puente Alto",
#         "region": "RM: Metropolitana de Santiago",
#         "phone": "569975796913",
#         "gender": "M",
#         "birthday": "1961-05-02",
#         "university": null,
#         "degree": "digitador",
#         "bank": "Falabella",
#         "account_type": "Corriente",
#         "account_number": "01-506-010540-2",
#         "nationality": "Chilena",
#         "civil_status": "Casado",
#         "health_company": "consalud",
#         "pension_regime": "afp",
#         "pension_fund": "habitat",
#         "active_until": null,
#         "afc": "no_cotiza",
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "1987-01-09",
#         "status": "activo",
#         "start_date": "2025-04-01",
#         "end_date": null,
#         "termination_reason": null,
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 4301,
#         "rut_boss": "13.911.264-4",
#         "base_wage": 2000000,
#         "contract_type": "Indefinido",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "Customer Service",
#         "area_id": 444,
#         "cost_center": "6001",
#         "ctrlit_recinto": "Lucerna -Remoto-Limitado",
#         "tipo_de_jornada_laboral": null
#     },
#     {
#         "person_id": 4834,
#         "id": 4853,
#         "full_name": "Daniel Elias Adonis Adones",
#         "rut": "20.162.645-5",
#         "email": "danieladonis153@gmail.com",
#         "personal_email": "danieladonis153@gmail.com",
#         "address": "Psje Puangue 6936",
#         "street": "",
#         "street_number": "",
#         "city": "Santiago",
#         "province": null,
#         "district": "Cerrillos",
#         "region": "RM: Metropolitana de Santiago",
#         "phone": "931962110",
#         "gender": "M",
#         "birthday": "1999-11-01",
#         "university": null,
#         "degree": null,
#         "bank": "Santander",
#         "account_type": "Corriente",
#         "account_number": "000085116266",
#         "nationality": "Chilena",
#         "civil_status": "Soltero",
#         "health_company": "fonasa",
#         "pension_regime": "afp",
#         "pension_fund": "modelo",
#         "active_until": null,
#         "afc": "normal",
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2022-04-25",
#         "status": "activo",
#         "start_date": "2025-07-01",
#         "end_date": null,
#         "termination_reason": null,
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 4591,
#         "rut_boss": "25.607.565-2",
#         "base_wage": 720000,
#         "contract_type": "Indefinido",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "Asistente De Laboratorio",
#         "area_id": 429,
#         "cost_center": "2011",
#         "ctrlit_recinto": "Lucerna -Reloj control",
#         "tipo_de_jornada_laboral": null
#     },
#     {
#         "person_id": 8231,
#         "id": 8250,
#         "full_name": "Hugo Enrique Adrian Medel",
#         "rut": "12.291.995-1",
#         "email": "he_adrianmedel@hotmail.com",
#         "personal_email": "he_adrianmedel@hotmail.com",
#         "address": "Bio Bio 1485, Edificio Plaza Depto 14",
#         "street": "",
#         "street_number": "",
#         "city": "Santiago",
#         "province": null,
#         "district": "Santiago",
#         "region": "RM: Metropolitana de Santiago",
#         "phone": "56942747062",
#         "gender": "M",
#         "birthday": "1972-06-03",
#         "university": "Inacap",
#         "degree": "Electricidad Industrial Mención Instalaciones Electricas",
#         "bank": "Banco Estado",
#         "account_type": "Corriente",
#         "account_number": "00003219429",
#         "nationality": "Chilena",
#         "civil_status": "Divorciado",
#         "health_company": "fonasa",
#         "pension_regime": "afp",
#         "pension_fund": "provida",
#         "active_until": null,
#         "afc": "normal",
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2024-08-05",
#         "status": "activo",
#         "start_date": "2025-04-01",
#         "end_date": null,
#         "termination_reason": null,
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 4678,
#         "rut_boss": "11.524.484-1",
#         "base_wage": 570000,
#         "contract_type": "Indefinido",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "Operario",
#         "area_id": 450,
#         "cost_center": "6005",
#         "ctrlit_recinto": "Lucerna -Reloj control",
#         "tipo_de_jornada_laboral": "Ordinaria"
#     },
#     {
#         "person_id": 4661,
#         "id": 4661,
#         "full_name": "David Jose Adrianza Medina",
#         "rut": "27.299.196-0",
#         "email": null,
#         "personal_email": "djam_88@hotmail.com",
#         "address": "Lib. Bernardo O'Higgins 4877 Dpto. 308",
#         "street": null,
#         "street_number": null,
#         "city": null,
#         "province": null,
#         "district": "Estación Central",
#         "region": "RM: Metropolitana de Santiago",
#         "phone": "949571836",
#         "gender": "M",
#         "birthday": "1992-01-06",
#         "university": null,
#         "degree": null,
#         "bank": "Santander",
#         "account_type": "Corriente",
#         "account_number": "76766339",
#         "nationality": "Venezolana",
#         "civil_status": "Soltero",
#         "health_company": "fonasa",
#         "pension_regime": "afp",
#         "pension_fund": "modelo",
#         "active_until": "2021-10-02",
#         "afc": "normal",
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2021-03-01",
#         "status": "inactivo",
#         "start_date": "2021-03-01",
#         "end_date": "2021-10-02",
#         "termination_reason": "renuncia",
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 4438,
#         "rut_boss": "17.255.753-8",
#         "base_wage": 503000,
#         "contract_type": "Indefinido",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "Analista De Control De Calidad",
#         "area_id": 49,
#         "cost_center": "6101",
#         "ctrlit_recinto": "sinrecinto",
#         "tipo_de_jornada_laboral": null
#     },
#     {
#         "person_id": 4539,
#         "id": 4539,
#         "full_name": "Ezequiel Enrique Aguero Tapia",
#         "rut": "19.199.937-1",
#         "email": "aguero.2258@gmail.com",
#         "personal_email": "aguero.2258@gmail.com",
#         "address": "Carlos Oviedo Block 340 Dpto. C-23",
#         "street": null,
#         "street_number": null,
#         "city": null,
#         "province": null,
#         "district": "Cerrillos",
#         "region": "RM: Metropolitana de Santiago",
#         "phone": null,
#         "gender": "M",
#         "birthday": "1991-08-27",
#         "university": null,
#         "degree": null,
#         "bank": "Scotiabank",
#         "account_type": "Corriente",
#         "account_number": "230144080",
#         "nationality": "Chilena",
#         "civil_status": "Soltero",
#         "health_company": "banmedica",
#         "pension_regime": "afp",
#         "pension_fund": "modelo",
#         "active_until": "2021-12-01",
#         "afc": "normal",
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2012-08-16",
#         "status": "inactivo",
#         "start_date": "2012-08-16",
#         "end_date": "2021-12-01",
#         "termination_reason": "mutuo_acuerdo",
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 4625,
#         "rut_boss": "26.689.690-5",
#         "base_wage": 800000,
#         "contract_type": "Indefinido",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "Supervisor De Planta",
#         "area_id": 42,
#         "cost_center": "6003",
#         "ctrlit_recinto": "lucerna",
#         "tipo_de_jornada_laboral": null
#     },
#     {
#         "person_id": 4262,
#         "id": 4262,
#         "full_name": "Jose Patricio Aguila Paiñel",
#         "rut": "13.056.536-0",
#         "email": null,
#         "personal_email": "aguilapainel@gmail.com",
#         "address": "El Esfuerzo 6189",
#         "street": null,
#         "street_number": null,
#         "city": null,
#         "province": null,
#         "district": "Cerrillos",
#         "region": "RM: Metropolitana de Santiago",
#         "phone": "933328361",
#         "gender": "M",
#         "birthday": "1976-09-04",
#         "university": null,
#         "degree": null,
#         "bank": "Banco Estado",
#         "account_type": "Corriente",
#         "account_number": "13056536",
#         "nationality": "Chilena",
#         "civil_status": "Soltero",
#         "health_company": "fonasa",
#         "pension_regime": "afp",
#         "pension_fund": "provida",
#         "active_until": "2019-12-20",
#         "afc": "normal",
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2018-06-06",
#         "status": "inactivo",
#         "start_date": "2018-06-06",
#         "end_date": "2019-12-20",
#         "termination_reason": "necesidades_empresa",
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 4262,
#         "rut_boss": "13.056.536-0",
#         "base_wage": 360000,
#         "contract_type": "Indefinido",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "Operario",
#         "area_id": 48,
#         "cost_center": "6013",
#         "ctrlit_recinto": "sinrecinto",
#         "tipo_de_jornada_laboral": null
#     },
#     {
#         "person_id": 4141,
#         "id": 4141,
#         "full_name": "Jose Aguilar Gonzalez",
#         "rut": "13.683.767-2",
#         "email": "jfaguilargonza@gmail.com",
#         "personal_email": "jfaguilargonza@gmail.com",
#         "address": "Chañaral Norte 1892",
#         "street": "",
#         "street_number": "",
#         "city": "",
#         "province": null,
#         "district": "Maipú",
#         "region": "RM: Metropolitana de Santiago",
#         "phone": "",
#         "gender": "M",
#         "birthday": "1979-09-21",
#         "university": null,
#         "degree": null,
#         "bank": "Falabella",
#         "account_type": "Corriente",
#         "account_number": "10070231170",
#         "nationality": "Chilena",
#         "civil_status": "Casado",
#         "health_company": "fonasa",
#         "pension_regime": "afp",
#         "pension_fund": "habitat",
#         "active_until": null,
#         "afc": "reducido",
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2008-02-11",
#         "status": "activo",
#         "start_date": "2025-04-01",
#         "end_date": null,
#         "termination_reason": null,
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 4529,
#         "rut_boss": "8.954.496-3",
#         "base_wage": 2373000,
#         "contract_type": "Indefinido",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "Key Account Manager",
#         "area_id": 427,
#         "cost_center": "2005",
#         "ctrlit_recinto": "Las Encinas-Sin marcaje",
#         "tipo_de_jornada_laboral": null
#     },
#     {
#         "person_id": 4589,
#         "id": 4589,
#         "full_name": "Zasha Vanessa Aguilar Boscan",
#         "rut": "25.537.281-5",
#         "email": "zasha.aguilar@gmail.com",
#         "personal_email": "zasha.aguilar@gmail.com",
#         "address": "Vargas Bustos 1051 Dpto. 1701",
#         "street": "",
#         "street_number": "",
#         "city": "",
#         "province": null,
#         "district": "San Miguel",
#         "region": "RM: Metropolitana de Santiago",
#         "phone": "965394733",
#         "gender": "F",
#         "birthday": "1991-03-15",
#         "university": null,
#         "degree": "Relaciones Industriales",
#         "bank": "Banco Estado",
#         "account_type": "Corriente",
#         "account_number": "32900026969",
#         "nationality": "Venezolana",
#         "civil_status": "Casado",
#         "health_company": "fonasa",
#         "pension_regime": "afp",
#         "pension_fund": "planvital",
#         "active_until": "2023-10-31",
#         "afc": "normal",
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2021-03-01",
#         "status": "inactivo",
#         "start_date": "2023-03-01",
#         "end_date": "2023-10-31",
#         "termination_reason": "necesidades_empresa",
#         "payment_method": "Cheque",
#         "id_boss": 4181,
#         "rut_boss": "9.919.072-8",
#         "base_wage": 650000,
#         "contract_type": "Indefinido",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "Customer Support",
#         "area_id": 87,
#         "cost_center": "3002",
#         "ctrlit_recinto": "lasencinas",
#         "tipo_de_jornada_laboral": null
#     },
#     {
#         "person_id": 4652,
#         "id": 4652,
#         "full_name": "Victor Aaron Aguilera Figueroa",
#         "rut": "18.052.545-9",
#         "email": null,
#         "personal_email": "aguilera.victor.figueroa@gmail.com",
#         "address": "GASPAR DE SOTO 541",
#         "street": null,
#         "street_number": null,
#         "city": null,
#         "province": null,
#         "district": "San Miguel",
#         "region": "RM: Metropolitana de Santiago",
#         "phone": "961388655",
#         "gender": "M",
#         "birthday": "1992-04-13",
#         "university": null,
#         "degree": null,
#         "bank": "Banco Estado",
#         "account_type": "Corriente",
#         "account_number": "18052545",
#         "nationality": "Chilena",
#         "civil_status": "Soltero",
#         "health_company": "consalud",
#         "pension_regime": "afp",
#         "pension_fund": "modelo",
#         "active_until": "2019-04-02",
#         "afc": "normal",
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2018-12-03",
#         "status": "inactivo",
#         "start_date": "2018-12-03",
#         "end_date": "2019-04-02",
#         "termination_reason": "vencimiento_plazo",
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 4652,
#         "rut_boss": "18.052.545-9",
#         "base_wage": 572500,
#         "contract_type": "Fijo",
#         "contract_finishing_date_1": "2019-04-02",
#         "contract_finishing_date_2": null,
#         "name_role": "Electromecánico",
#         "area_id": 50,
#         "cost_center": "6102",
#         "ctrlit_recinto": "sinrecinto",
#         "tipo_de_jornada_laboral": null
#     },
#     {
#         "person_id": 4139,
#         "id": 4139,
#         "full_name": "Flaminio Del Carmen Agurto Urrutia",
#         "rut": "8.606.991-1",
#         "email": "agurtoflaminio@gmail.com",
#         "personal_email": "agurtoflaminio@gmail.com",
#         "address": "El Huaina 1743",
#         "street": null,
#         "street_number": null,
#         "city": "",
#         "province": null,
#         "district": "Maipú",
#         "region": "RM: Metropolitana de Santiago",
#         "phone": "",
#         "gender": "M",
#         "birthday": "1960-11-14",
#         "university": null,
#         "degree": null,
#         "bank": "Banco Estado",
#         "account_type": "Corriente",
#         "account_number": "31300005210",
#         "nationality": "Chilena",
#         "civil_status": "Casado",
#         "health_company": "fonasa",
#         "pension_regime": "afp",
#         "pension_fund": "provida",
#         "active_until": null,
#         "afc": "reducido",
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "1993-11-17",
#         "status": "activo",
#         "start_date": "2025-04-01",
#         "end_date": null,
#         "termination_reason": null,
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 4669,
#         "rut_boss": "10.947.411-8",
#         "base_wage": 1220000,
#         "contract_type": "Indefinido",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "Chofer",
#         "area_id": 477,
#         "cost_center": "6205",
#         "ctrlit_recinto": "Lucerna -Reloj control",
#         "tipo_de_jornada_laboral": null
#     },
#     {
#         "person_id": 4830,
#         "id": 4849,
#         "full_name": "Marcela Gisselle Álamos Silva",
#         "rut": "18.332.520-5",
#         "email": "marcela_alamos.s@hotmail.com",
#         "personal_email": "marcela_alamos.s@hotmail.com",
#         "address": "Coquimbito Sur Sitio 27 A",
#         "street": "",
#         "street_number": "",
#         "city": "Santiago",
#         "province": null,
#         "district": "Tiltil",
#         "region": "RM: Metropolitana de Santiago",
#         "phone": "978292798",
#         "gender": "F",
#         "birthday": "1994-06-25",
#         "university": "Instituto Profesional AIEP",
#         "degree": "Técnico Nivel Superior en Enfermería ",
#         "bank": "Banco de Chile",
#         "account_type": "Corriente",
#         "account_number": "03620652608",
#         "nationality": "Chilena",
#         "civil_status": "Soltero",
#         "health_company": "fonasa",
#         "pension_regime": "afp",
#         "pension_fund": "modelo",
#         "active_until": null,
#         "afc": "normal",
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2022-04-18",
#         "status": "activo",
#         "start_date": "2025-04-01",
#         "end_date": null,
#         "termination_reason": null,
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 4175,
#         "rut_boss": "9.093.920-3",
#         "base_wage": 892000,
#         "contract_type": "Indefinido",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "Coordinadora Muestras",
#         "area_id": 432,
#         "cost_center": "3001",
#         "ctrlit_recinto": "Lucerna -Reloj control",
#         "tipo_de_jornada_laboral": null
#     },
#     {
#         "person_id": 4728,
#         "id": 4728,
#         "full_name": "Francisca Constanza Alarcon Madariaga",
#         "rut": "19.292.232-1",
#         "email": "fran.alarconm11@gmail.com",
#         "personal_email": "fran.alarconm11@gmail.com",
#         "address": "Montevideo 412",
#         "street": "",
#         "street_number": "",
#         "city": "",
#         "province": null,
#         "district": "Padre Hurtado",
#         "region": "RM: Metropolitana de Santiago",
#         "phone": "987268640",
#         "gender": "F",
#         "birthday": "1996-03-20",
#         "university": null,
#         "degree": "Tecnico Medio Laboratorio Quimico",
#         "bank": "Banco de Chile",
#         "account_type": "Corriente",
#         "account_number": "000006522131",
#         "nationality": "Chilena",
#         "civil_status": "Soltero",
#         "health_company": "fonasa",
#         "pension_regime": "afp",
#         "pension_fund": "habitat",
#         "active_until": null,
#         "afc": "normal",
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2020-01-06",
#         "status": "activo",
#         "start_date": "2025-07-01",
#         "end_date": null,
#         "termination_reason": null,
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 4514,
#         "rut_boss": "18.567.094-5",
#         "base_wage": 800000,
#         "contract_type": "Indefinido",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "Asistente De Laboratorio",
#         "area_id": 422,
#         "cost_center": "2003",
#         "ctrlit_recinto": "Lucerna -Reloj control",
#         "tipo_de_jornada_laboral": null
#     },
#     {
#         "person_id": 4573,
#         "id": 4573,
#         "full_name": "Javier Alonso Alarcon Andrade",
#         "rut": "20.729.014-9",
#         "email": "jajo.alarcon@gmail.com",
#         "personal_email": "jajo.alarcon@gmail.com",
#         "address": "El Litre 8196",
#         "street": "",
#         "street_number": "",
#         "city": "",
#         "province": null,
#         "district": "Cerrillos",
#         "region": "RM: Metropolitana de Santiago",
#         "phone": "946882466",
#         "gender": "M",
#         "birthday": "2001-03-25",
#         "university": null,
#         "degree": null,
#         "bank": "BCI",
#         "account_type": "Corriente",
#         "account_number": "89151372",
#         "nationality": "Chilena",
#         "civil_status": "Soltero",
#         "health_company": "fonasa",
#         "pension_regime": "afp",
#         "pension_fund": "uno",
#         "active_until": null,
#         "afc": "normal",
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2021-06-01",
#         "status": "activo",
#         "start_date": "2025-04-01",
#         "end_date": null,
#         "termination_reason": null,
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 4704,
#         "rut_boss": "12.119.527-5",
#         "base_wage": 740000,
#         "contract_type": "Indefinido",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "Ayudante De Bodega",
#         "area_id": 474,
#         "cost_center": "6204",
#         "ctrlit_recinto": "Lucerna -Reloj control",
#         "tipo_de_jornada_laboral": null
#     },
#     {
#         "person_id": 4457,
#         "id": 4457,
#         "full_name": "Karen Lissette Alarcon Rios",
#         "rut": "17.473.896-3",
#         "email": null,
#         "personal_email": "karen.alarcon90@gmail.com",
#         "address": "FERNANDO RIOJA 145 Dpto. 407",
#         "street": null,
#         "street_number": null,
#         "city": null,
#         "province": null,
#         "district": "La Cisterna",
#         "region": "RM: Metropolitana de Santiago",
#         "phone": "988437546",
#         "gender": "F",
#         "birthday": "1990-03-23",
#         "university": null,
#         "degree": null,
#         "bank": "Banco de Chile",
#         "account_type": "Corriente",
#         "account_number": "24016215",
#         "nationality": "Chilena",
#         "civil_status": "Soltero",
#         "health_company": "consalud",
#         "pension_regime": "afp",
#         "pension_fund": "habitat",
#         "active_until": "2021-04-01",
#         "afc": "normal",
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2018-10-01",
#         "status": "inactivo",
#         "start_date": "2018-10-01",
#         "end_date": "2021-04-01",
#         "termination_reason": "renuncia",
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 4457,
#         "rut_boss": "17.473.896-3",
#         "base_wage": 550000,
#         "contract_type": "Indefinido",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "Analista De Microbiología",
#         "area_id": 49,
#         "cost_center": "6101",
#         "ctrlit_recinto": "sinrecinto",
#         "tipo_de_jornada_laboral": null
#     },
#     {
#         "person_id": 4614,
#         "id": 4614,
#         "full_name": "Mariana Rosiel Alarcon Valera",
#         "rut": "26.387.629-6",
#         "email": "mari.alarcon94@gmail.com",
#         "personal_email": "mari.alarcon94@gmail.com",
#         "address": "Salesianos 1128 Dpto. 1403B",
#         "street": null,
#         "street_number": null,
#         "city": null,
#         "province": null,
#         "district": "San Miguel",
#         "region": "RM: Metropolitana de Santiago",
#         "phone": "948114045",
#         "gender": "F",
#         "birthday": "1994-09-06",
#         "university": null,
#         "degree": "Quimico",
#         "bank": "Falabella",
#         "account_type": "Corriente",
#         "account_number": "15270090174",
#         "nationality": "Venezolana",
#         "civil_status": "Soltero",
#         "health_company": "fonasa",
#         "pension_regime": "afp",
#         "pension_fund": "modelo",
#         "active_until": "2022-05-27",
#         "afc": "normal",
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2020-10-05",
#         "status": "inactivo",
#         "start_date": "2020-10-05",
#         "end_date": "2022-05-27",
#         "termination_reason": "necesidades_empresa",
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 4485,
#         "rut_boss": "17.960.137-0",
#         "base_wage": 550000,
#         "contract_type": "Indefinido",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "Asistente De Laboratorio",
#         "area_id": 98,
#         "cost_center": "2001",
#         "ctrlit_recinto": "lasencinas",
#         "tipo_de_jornada_laboral": null
#     },
#     {
#         "person_id": 9485,
#         "id": 9504,
#         "full_name": "Anny Belén Alarcón Campos",
#         "rut": "19.418.607-k",
#         "email": "aba.alarcon@gmail.com",
#         "personal_email": "aba.alarcon@gmail.com",
#         "address": "Fuenzalida Urrejola #1170",
#         "street": "",
#         "street_number": "",
#         "city": "Santiago",
#         "province": null,
#         "district": "La Cisterna",
#         "region": "RM: Metropolitana de Santiago",
#         "phone": "56985842588",
#         "gender": "F",
#         "birthday": "1996-11-30",
#         "university": "Pontificia Universidad Católica de Chile",
#         "degree": "Licenciada en Química",
#         "bank": "Santander",
#         "account_type": "Corriente",
#         "account_number": "000073824338",
#         "nationality": "Chilena",
#         "civil_status": "Soltero",
#         "health_company": "fonasa",
#         "pension_regime": "afp",
#         "pension_fund": "modelo",
#         "active_until": "2025-04-30",
#         "afc": "normal",
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2025-02-03",
#         "status": "inactivo",
#         "start_date": "2025-04-01",
#         "end_date": "2025-04-30",
#         "termination_reason": "vencimiento_plazo",
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 4380,
#         "rut_boss": "16.286.890-k",
#         "base_wage": 973000,
#         "contract_type": "Fijo",
#         "contract_finishing_date_1": "2025-05-02",
#         "contract_finishing_date_2": null,
#         "name_role": "Analista Cromatográfico",
#         "area_id": 418,
#         "cost_center": "2001",
#         "ctrlit_recinto": "Lucerna -Reloj control",
#         "tipo_de_jornada_laboral": "Ordinaria"
#     },
#     {
#         "person_id": 4468,
#         "id": 4468,
#         "full_name": "Matilde Ivette Albagli Cohen",
#         "rut": "17.702.432-5",
#         "email": "malbaglic@gmail.com",
#         "personal_email": "malbaglic@gmail.com",
#         "address": "Av. Cristobal Colon 4362 Dpto. 74A",
#         "street": null,
#         "street_number": null,
#         "city": "",
#         "province": null,
#         "district": "Las Condes",
#         "region": "RM: Metropolitana de Santiago",
#         "phone": "994733789",
#         "gender": "F",
#         "birthday": "1991-05-20",
#         "university": null,
#         "degree": "Ingeniero Comercial",
#         "bank": "Banco de Chile",
#         "account_type": "Corriente",
#         "account_number": "360278908",
#         "nationality": "Chilena",
#         "civil_status": "Casado",
#         "health_company": "colmena",
#         "pension_regime": "afp",
#         "pension_fund": "habitat",
#         "active_until": "2022-01-12",
#         "afc": "normal",
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2020-10-19",
#         "status": "inactivo",
#         "start_date": "2020-10-19",
#         "end_date": "2022-01-12",
#         "termination_reason": "renuncia",
#         "payment_method": "No Generar Pago",
#         "id_boss": 4328,
#         "rut_boss": "15.377.760-8",
#         "base_wage": 1751000,
#         "contract_type": "Indefinido",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "Comprador Internacional",
#         "area_id": 8,
#         "cost_center": "6201",
#         "ctrlit_recinto": "lucerna",
#         "tipo_de_jornada_laboral": null
#     },
#     {
#         "person_id": 4912,
#         "id": 4931,
#         "full_name": "Katiuska Nataly Alcota Huirimilla",
#         "rut": "16.986.937-5",
#         "email": "kalcota@cramer.cl",
#         "personal_email": "katiuskaalcota@gmail.com",
#         "address": "Placer 1156, depto 221",
#         "street": "",
#         "street_number": "",
#         "city": "Santiago",
#         "province": null,
#         "district": "Santiago",
#         "region": "RM: Metropolitana de Santiago",
#         "phone": "923899666",
#         "gender": "F",
#         "birthday": "1987-06-30",
#         "university": "Inacap",
#         "degree": "Nivel Superior en Análisis Químico ",
#         "bank": "Banco Estado",
#         "account_type": "Vista",
#         "account_number": "16986937",
#         "nationality": "Chilena",
#         "civil_status": "Soltero",
#         "health_company": "fonasa",
#         "pension_regime": "afp",
#         "pension_fund": "modelo",
#         "active_until": "2025-07-03",
#         "afc": "normal",
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2022-10-17",
#         "status": "inactivo",
#         "start_date": "2025-04-01",
#         "end_date": "2025-07-03",
#         "termination_reason": "renuncia",
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 4502,
#         "rut_boss": "18.357.635-6",
#         "base_wage": 716000,
#         "contract_type": "Indefinido",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "Analista De Control De Calidad",
#         "area_id": 458,
#         "cost_center": "6101",
#         "ctrlit_recinto": "Lucerna -Reloj control",
#         "tipo_de_jornada_laboral": null
#     }
# ]
