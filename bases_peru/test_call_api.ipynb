# %%
import requests
import os
import pymysql
import time
import json
import datetime
from datetime import timedelta
import sys


# Configuración API
URL = "https://cramerperu.buk.pe/api/v1/peru/employees"
TOKEN = "HQfVBfeZJVGNn3dthsX8Acp5"

# Configuración BD - windows
DB_HOST = "192.168.245.33"
DB_USER = "compensaciones_rrhh"
DB_PASSWORD = "_Cramercomp2025_"
DB_NAME = "rrhh_app"

# %%
def obtener_todos_los_empleados_filtrados():
    """Sincroniza empleados y genera alertas (ejecución programada por Windows)."""
    headers = {"auth_token": TOKEN}
    empleados_filtrados = []
    url_actual = URL
    pagina_actual = 1
    
    print("obtención de los datos")
    
    while url_actual and pagina_actual <= 1:  
        print(f"Obteniendo página {pagina_actual}...")
        
        try:
            respuesta = requests.get(url_actual, headers=headers)
            respuesta.raise_for_status()
            
            respuesta_api = respuesta.json()
            empleados_pagina = respuesta_api['data']
            pagination_info = respuesta_api['pagination']
            
            # Filtrar cada empleado de esta página
            for empleado_completo in empleados_pagina:
                empleado_filtrado = {
                #información Personal
                "person_id": empleado_completo.get("person_id"),
                "id": empleado_completo.get("id"),
                "full_name": empleado_completo.get("full_name"),
                "document_type": empleado_completo.get("document_type"),  
                "document_number": empleado_completo.get("document_number"),
                "email": empleado_completo.get("email"),
                "personal_email": empleado_completo.get("personal_email"),
                "address": empleado_completo.get("address"),
                "province": empleado_completo.get("provincia"),
                "district": empleado_completo.get("distrito"),
                "city": empleado_completo.get("departamento"),
                "phone": empleado_completo.get("phone"),
                "gender": empleado_completo.get("gender"),
                "birthday": empleado_completo.get("birthday"),
                "university": empleado_completo.get("university"),
                "education_status": empleado_completo.get("education_status"),
                "active_since": empleado_completo.get("active_since"),
                "status": empleado_completo.get("status"),
                "payment_method": empleado_completo.get("payment_method"),
                
                "degree": empleado_completo.get("degree"),
                "bank": empleado_completo.get("bank"),
                "account_type": empleado_completo.get("account_type"),
                "account_number": empleado_completo.get("account_number"),
                "nationality": empleado_completo.get("nationality"),
                "civil_status": empleado_completo.get("civil_status"),
                "health_company": empleado_completo.get("health_company"),
                "pension_regime": empleado_completo.get("pension_regime"),
                "pension_fund": empleado_completo.get("pension_fund"),
                "active_until": empleado_completo.get("active_until"),
                "afc": empleado_completo.get("afc"),
                "retired": empleado_completo.get("retired"),
                "retirement_regime": empleado_completo.get("retirement_regime"),
                #Información Laboral
                
                "start_date": empleado_completo.get("current_job", {}).get("start_date"),
                "end_date": empleado_completo.get("current_job", {}).get("end_date"),
                "termination_reason": empleado_completo.get("termination_reason"),
                
                "id_boss": empleado_completo.get("current_job", {}).get("boss", {}).get("id"),
                "rut_boss": empleado_completo.get("current_job", {}).get("boss", {}).get("rut"),
                "base_wage": empleado_completo.get("current_job", {}).get("base_wage",),
                "contract_type": empleado_completo.get("current_job", {}).get("contract_type"),
                "contract_finishing_date_1": empleado_completo.get("current_job", {}).get("contract_finishing_date_1"),
                "contract_finishing_date_2": empleado_completo.get("current_job", {}).get("contract_finishing_date_2"),
                'name_role': empleado_completo.get("current_job", {}).get("role", {}).get("name"),
                'area_id': empleado_completo.get("current_job", {}).get("area_id"),
                "cost_center": empleado_completo.get("current_job", {}).get("cost_center"),
                "ctrlit_recinto": empleado_completo.get("current_job", {}).get("custom_attributes", {}).get("ctrlit_recinto"),
                }
                empleados_filtrados.append(empleado_filtrado)
            
            
            # Obtener la URL de la siguiente página
            url_actual = pagination_info.get('next')
            pagina_actual += 1
            
            # Pequeña pausa para no sobrecargar la API
            time.sleep(0.5)
            
        except requests.exceptions.RequestException as e:
            print(f"❌ Error en la petición: {e}")
            break
            
    print(f"Paginación completa!! empleados filtrados: {len(empleados_filtrados)}")
    print(json.dumps(empleados_filtrados, indent=4, ensure_ascii=False))

    return empleados_filtrados

# %%
if __name__ == "__main__":
    
    # Ejecutar SOLO UNA VEZ (para el Programador de Tareas)
    print("🔍 Ejecutando sincronización programada...")
    obtener_todos_los_empleados_filtrados()
# Out:
# 🔍 Ejecutando sincronización programada...
# obtención de los datos
# Obteniendo página 1...
# Paginación completa!! empleados filtrados: 25
# [
#     {
#         "person_id": 485,
#         "id": 406,
#         "full_name": "Nolberto Geremy Aburto Avila",
#         "rut": null,
#         "email": "geremy2ble@gmail.com",
#         "personal_email": "geremy2ble@gmail.com",
#         "address": "JULIO C TELLO MZ U LT 7",
#         "street": null,
#         "street_number": null,
#         "city": null,
#         "province": null,
#         "district": null,
#         "region": null,
#         "phone": "968927782",
#         "gender": "M",
#         "birthday": "2002-08-10",
#         "university": null,
#         "degree": null,
#         "bank": "Banco de Crédito del Perú",
#         "account_type": "Cuenta de Ahorros",
#         "account_number": "00219110403820309257",
#         "nationality": "Peruana",
#         "civil_status": "Soltero",
#         "health_company": "es_salud",
#         "pension_regime": "afp",
#         "pension_fund": "integra",
#         "active_until": null,
#         "afc": null,
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2025-04-21",
#         "status": "activo",
#         "start_date": "2025-09-01",
#         "end_date": null,
#         "termination_reason": null,
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 366,
#         "rut_boss": null,
#         "base_wage": 1300,
#         "contract_type": "Contrato a Plazo Indeterminado",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "AUXILIAR DE ALMACÉN",
#         "area_id": 7,
#         "cost_center": "1151",
#         "ctrlit_recinto": null
#     },
#     {
#         "person_id": 473,
#         "id": 380,
#         "full_name": "Victor Antonio Acosta Revilla",
#         "rut": null,
#         "email": null,
#         "personal_email": null,
#         "address": "JIRON ALEJANDRO AYARZA 172 URB EL BOSQUE",
#         "street": null,
#         "street_number": null,
#         "city": null,
#         "province": null,
#         "district": null,
#         "region": null,
#         "phone": "",
#         "gender": "M",
#         "birthday": "1999-12-30",
#         "university": null,
#         "degree": null,
#         "bank": "Interbank",
#         "account_type": "Cuenta de Ahorros",
#         "account_number": "00382101335317208464",
#         "nationality": "Peruana",
#         "civil_status": "Soltero",
#         "health_company": "es_salud",
#         "pension_regime": "afp",
#         "pension_fund": "integra",
#         "active_until": "2024-11-25",
#         "afc": null,
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2024-11-05",
#         "status": "inactivo",
#         "start_date": "2024-11-05",
#         "end_date": "2024-11-25",
#         "termination_reason": "despido",
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 375,
#         "rut_boss": null,
#         "base_wage": 1500,
#         "contract_type": "Contrato a Plazo Indeterminado",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "ASISTENTE LABORATORIO",
#         "area_id": 16,
#         "cost_center": "1201",
#         "ctrlit_recinto": null
#     },
#     {
#         "person_id": 473,
#         "id": 393,
#         "full_name": "Victor Antonio Acosta Revilla",
#         "rut": null,
#         "email": null,
#         "personal_email": null,
#         "address": "JIRON ALEJANDRO AYARZA 172 URB EL BOSQUE",
#         "street": null,
#         "street_number": null,
#         "city": null,
#         "province": null,
#         "district": null,
#         "region": null,
#         "phone": "",
#         "gender": "M",
#         "birthday": "1999-12-30",
#         "university": null,
#         "degree": null,
#         "bank": "Interbank",
#         "account_type": "Cuenta de Ahorros",
#         "account_number": "00382101335317208464",
#         "nationality": "Peruana",
#         "civil_status": "Soltero",
#         "health_company": "es_salud",
#         "pension_regime": "afp",
#         "pension_fund": "integra",
#         "active_until": "2025-03-01",
#         "afc": null,
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2025-03-01",
#         "status": "inactivo",
#         "start_date": "2025-03-01",
#         "end_date": "2025-03-01",
#         "termination_reason": "renuncia",
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 375,
#         "rut_boss": null,
#         "base_wage": 1500,
#         "contract_type": "Contrato a Plazo Indeterminado",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "ASISTENTE LABORATORIO",
#         "area_id": 16,
#         "cost_center": "1201",
#         "ctrlit_recinto": null
#     },
#     {
#         "person_id": 399,
#         "id": 306,
#         "full_name": "David Randolf Amado Santiago",
#         "rut": null,
#         "email": "d.amadosantiago@gmail.com",
#         "personal_email": "d.amadosantiago@gmail.com",
#         "address": "Cooperativa de Vivienda, Hijos Garagay, Mz A Lote 11",
#         "street": null,
#         "street_number": null,
#         "city": null,
#         "province": null,
#         "district": null,
#         "region": null,
#         "phone": "982370408",
#         "gender": "M",
#         "birthday": "1990-04-22",
#         "university": null,
#         "degree": null,
#         "bank": "BBVA Continental",
#         "account_type": "Cuenta de Ahorros",
#         "account_number": "001101420200743787",
#         "nationality": "Peruana",
#         "civil_status": "Soltero",
#         "health_company": "es_salud",
#         "pension_regime": "afp",
#         "pension_fund": "prima",
#         "active_until": null,
#         "afc": null,
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2014-08-18",
#         "status": "activo",
#         "start_date": "2025-01-01",
#         "end_date": null,
#         "termination_reason": null,
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 330,
#         "rut_boss": null,
#         "base_wage": 4600,
#         "contract_type": "Contrato a Plazo Indeterminado",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "ASISTENTE LABORATORIO SALADOS",
#         "area_id": 18,
#         "cost_center": "1201",
#         "ctrlit_recinto": null
#     },
#     {
#         "person_id": 501,
#         "id": 420,
#         "full_name": "Cesar Alexis Angulo Mendoza",
#         "rut": null,
#         "email": "alexis.jc_17@hotmail.com",
#         "personal_email": "alexis.jc_17@hotmail.com",
#         "address": "CALLE 2 MZ H LOTE 8 AH EL SANTUARIO",
#         "street": null,
#         "street_number": null,
#         "city": null,
#         "province": null,
#         "district": null,
#         "region": null,
#         "phone": "947372146",
#         "gender": "M",
#         "birthday": "1994-06-03",
#         "university": null,
#         "degree": null,
#         "bank": "Scotiabank",
#         "account_type": "Cuenta de Ahorros",
#         "account_number": "00902220081038780350",
#         "nationality": "Peruana",
#         "civil_status": "Soltero",
#         "health_company": "es_salud",
#         "pension_regime": "afp",
#         "pension_fund": "sistema_nacional",
#         "active_until": null,
#         "afc": null,
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2025-09-04",
#         "status": "activo",
#         "start_date": "2025-09-04",
#         "end_date": null,
#         "termination_reason": null,
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 366,
#         "rut_boss": null,
#         "base_wage": 1300,
#         "contract_type": "Obra determinada",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "AUXILIAR DE ALMACÉN",
#         "area_id": 7,
#         "cost_center": "1151",
#         "ctrlit_recinto": null
#     },
#     {
#         "person_id": 400,
#         "id": 307,
#         "full_name": "Claudia Virginia Anlas Valdivia",
#         "rut": null,
#         "email": null,
#         "personal_email": null,
#         "address": "BLOCK A18, DPTO 404, CONJUNTO HABITACIONAL VICUS",
#         "street": null,
#         "street_number": null,
#         "city": null,
#         "province": null,
#         "district": null,
#         "region": null,
#         "phone": "",
#         "gender": "F",
#         "birthday": "1985-08-15",
#         "university": null,
#         "degree": null,
#         "bank": "BBVA Continental",
#         "account_type": "Cuenta de Ahorros",
#         "account_number": "001101420201020657",
#         "nationality": "Peruana",
#         "civil_status": "Casado",
#         "health_company": "mapfre",
#         "pension_regime": "afp",
#         "pension_fund": "profuturo",
#         "active_until": "2023-11-17",
#         "afc": null,
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2019-11-21",
#         "status": "inactivo",
#         "start_date": "2023-10-01",
#         "end_date": "2023-11-17",
#         "termination_reason": "mutuo_disenso",
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 324,
#         "rut_boss": null,
#         "base_wage": 2575,
#         "contract_type": "Contrato a Plazo Indeterminado",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "ASISTENTE DE ADMINISTRACIÓN Y SERVICIO AL CLIENTE",
#         "area_id": 4,
#         "cost_center": "1201",
#         "ctrlit_recinto": null
#     },
#     {
#         "person_id": 401,
#         "id": 308,
#         "full_name": "Waldo Aponte Valderrama",
#         "rut": null,
#         "email": "w.r_libra5@hotmail.com",
#         "personal_email": "w.r_libra5@hotmail.com",
#         "address": "St. 1 Epo. 19, Manzana E, Lote 10",
#         "street": null,
#         "street_number": null,
#         "city": null,
#         "province": null,
#         "district": null,
#         "region": null,
#         "phone": "902063646",
#         "gender": "M",
#         "birthday": "1990-10-03",
#         "university": null,
#         "degree": null,
#         "bank": "BBVA Continental",
#         "account_type": "Cuenta de Ahorros",
#         "account_number": "001100570253108763",
#         "nationality": "Peruana",
#         "civil_status": "Conviviente",
#         "health_company": "es_salud",
#         "pension_regime": "afp",
#         "pension_fund": "prima",
#         "active_until": null,
#         "afc": null,
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2020-07-03",
#         "status": "activo",
#         "start_date": "2025-01-01",
#         "end_date": null,
#         "termination_reason": null,
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 366,
#         "rut_boss": null,
#         "base_wage": 1830,
#         "contract_type": "Contrato a Plazo Indeterminado",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "AUXILIAR DE ALMACÉN",
#         "area_id": 7,
#         "cost_center": "1151",
#         "ctrlit_recinto": null
#     },
#     {
#         "person_id": 489,
#         "id": 410,
#         "full_name": "Roxana Avalos Chacchi",
#         "rut": null,
#         "email": "chana_93_13@hotmail.com",
#         "personal_email": "chana_93_13@hotmail.com",
#         "address": "Mz A Lt 26 Urb. Villa Horizonte de San Diego",
#         "street": null,
#         "street_number": null,
#         "city": null,
#         "province": null,
#         "district": null,
#         "region": null,
#         "phone": "998808750",
#         "gender": "F",
#         "birthday": "1993-01-30",
#         "university": null,
#         "degree": null,
#         "bank": "Banco de Crédito del Perú",
#         "account_type": "Cuenta de Ahorros",
#         "account_number": "00219110550573905153",
#         "nationality": "Peruana",
#         "civil_status": "Soltero",
#         "health_company": "es_salud",
#         "pension_regime": "afp",
#         "pension_fund": "prima",
#         "active_until": null,
#         "afc": null,
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2025-04-01",
#         "status": "activo",
#         "start_date": "2025-05-01",
#         "end_date": null,
#         "termination_reason": null,
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 327,
#         "rut_boss": null,
#         "base_wage": 3200,
#         "contract_type": "Contrato a Plazo Indeterminado",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "ASISTENTE DE ADMINISTRACIÓN Y SERVICIO AL CLIENTE",
#         "area_id": 9,
#         "cost_center": "1151",
#         "ctrlit_recinto": null
#     },
#     {
#         "person_id": 402,
#         "id": 394,
#         "full_name": "Alexander Cabanillas Gallardo",
#         "rut": null,
#         "email": null,
#         "personal_email": null,
#         "address": "Urbanización, Jorge Chavez, 224, 1ra etapa",
#         "street": null,
#         "street_number": null,
#         "city": null,
#         "province": null,
#         "district": null,
#         "region": null,
#         "phone": "",
#         "gender": "M",
#         "birthday": "1992-03-29",
#         "university": null,
#         "degree": null,
#         "bank": "BBVA Continental",
#         "account_type": "Cuenta de Ahorros",
#         "account_number": "001101130200583595",
#         "nationality": "Peruana",
#         "civil_status": "Soltero",
#         "health_company": "mapfre",
#         "pension_regime": "afp",
#         "pension_fund": "integra",
#         "active_until": "2025-03-01",
#         "afc": null,
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2025-03-01",
#         "status": "inactivo",
#         "start_date": "2025-03-01",
#         "end_date": "2025-03-01",
#         "termination_reason": "renuncia",
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 322,
#         "rut_boss": null,
#         "base_wage": 7370,
#         "contract_type": "Contrato a Plazo Indeterminado",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "JEFE DE ALMACEN",
#         "area_id": 7,
#         "cost_center": "1151",
#         "ctrlit_recinto": null
#     },
#     {
#         "person_id": 402,
#         "id": 309,
#         "full_name": "Alexander Cabanillas Gallardo",
#         "rut": null,
#         "email": null,
#         "personal_email": null,
#         "address": "Urbanización, Jorge Chavez, 224, 1ra etapa",
#         "street": null,
#         "street_number": null,
#         "city": null,
#         "province": null,
#         "district": null,
#         "region": null,
#         "phone": "",
#         "gender": "M",
#         "birthday": "1992-03-29",
#         "university": null,
#         "degree": null,
#         "bank": "BBVA Continental",
#         "account_type": "Cuenta de Ahorros",
#         "account_number": "001101130200583595",
#         "nationality": "Peruana",
#         "civil_status": "Soltero",
#         "health_company": "mapfre",
#         "pension_regime": "afp",
#         "pension_fund": "integra",
#         "active_until": "2024-02-22",
#         "afc": null,
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2017-06-15",
#         "status": "inactivo",
#         "start_date": "2024-01-01",
#         "end_date": "2024-02-22",
#         "termination_reason": "mutuo_disenso",
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 322,
#         "rut_boss": null,
#         "base_wage": 7370,
#         "contract_type": "Contrato a Plazo Indeterminado",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "JEFE DE ALMACEN",
#         "area_id": 7,
#         "cost_center": "1151",
#         "ctrlit_recinto": null
#     },
#     {
#         "person_id": 403,
#         "id": 310,
#         "full_name": "Miguel Angel Cacsire Saboya",
#         "rut": null,
#         "email": "miguelcacsire04@gmail.com",
#         "personal_email": "miguelcacsire04@gmail.com",
#         "address": "Barrio 4, Sector 2, 4ta. Etapa, Manzana “M”, Lote 36",
#         "street": null,
#         "street_number": null,
#         "city": null,
#         "province": null,
#         "district": null,
#         "region": null,
#         "phone": "901753478",
#         "gender": "M",
#         "birthday": "1983-05-04",
#         "university": null,
#         "degree": null,
#         "bank": "BBVA Continental",
#         "account_type": "Cuenta de Ahorros",
#         "account_number": "001100570253099861",
#         "nationality": "Peruana",
#         "civil_status": "Casado",
#         "health_company": "es_salud",
#         "pension_regime": "afp",
#         "pension_fund": "integra",
#         "active_until": null,
#         "afc": null,
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2020-07-18",
#         "status": "activo",
#         "start_date": "2025-01-01",
#         "end_date": null,
#         "termination_reason": null,
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 366,
#         "rut_boss": null,
#         "base_wage": 4500,
#         "contract_type": "Contrato a Plazo Indeterminado",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "SUPERVISOR DE GRUPO",
#         "area_id": 7,
#         "cost_center": "1151",
#         "ctrlit_recinto": null
#     },
#     {
#         "person_id": 404,
#         "id": 311,
#         "full_name": "Carmen Luisa Calisaya Huaman",
#         "rut": null,
#         "email": "carmencali2@hotmail.com",
#         "personal_email": "carmencali2@hotmail.com",
#         "address": "Jiron, Jose Santos Figueroa, 134, Santa Luzmila",
#         "street": null,
#         "street_number": null,
#         "city": null,
#         "province": null,
#         "district": null,
#         "region": null,
#         "phone": "957378069",
#         "gender": "F",
#         "birthday": "1978-02-18",
#         "university": null,
#         "degree": null,
#         "bank": "BBVA Continental",
#         "account_type": "Cuenta de Ahorros",
#         "account_number": "001105790201583488",
#         "nationality": "Peruana",
#         "civil_status": "Casado",
#         "health_company": "mapfre",
#         "pension_regime": "afp",
#         "pension_fund": "sistema_nacional",
#         "active_until": null,
#         "afc": null,
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2022-02-15",
#         "status": "activo",
#         "start_date": "2025-01-01",
#         "end_date": null,
#         "termination_reason": null,
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 333,
#         "rut_boss": null,
#         "base_wage": 3250,
#         "contract_type": "Contrato a Plazo Indeterminado",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "GESTOR DE COBRANZA",
#         "area_id": 8,
#         "cost_center": "1151",
#         "ctrlit_recinto": null
#     },
#     {
#         "person_id": 468,
#         "id": 375,
#         "full_name": "Liliana Isabel Camarena De La Cruz",
#         "rut": null,
#         "email": "lcamarenadelacruz@gmail.com",
#         "personal_email": "lcamarenadelacruz@gmail.com",
#         "address": "CALLE PONGO DE RENTEMA MZ A LT 1",
#         "street": null,
#         "street_number": null,
#         "city": null,
#         "province": null,
#         "district": null,
#         "region": null,
#         "phone": "994335464",
#         "gender": "F",
#         "birthday": "1975-08-11",
#         "university": "260000020",
#         "degree": "511086",
#         "bank": "Banco de Crédito del Perú",
#         "account_type": "Cuenta de Ahorros",
#         "account_number": "00219319032619908218",
#         "nationality": "Peruana",
#         "civil_status": "Casado",
#         "health_company": "mapfre",
#         "pension_regime": "afp",
#         "pension_fund": "prima",
#         "active_until": null,
#         "afc": null,
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2024-09-09",
#         "status": "activo",
#         "start_date": "2024-10-01",
#         "end_date": null,
#         "termination_reason": null,
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 322,
#         "rut_boss": null,
#         "base_wage": 5000,
#         "contract_type": "Contrato a Plazo Indeterminado",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "COORDINADORA LABORATORIO FRAGANCIAS",
#         "area_id": 16,
#         "cost_center": "1201",
#         "ctrlit_recinto": null
#     },
#     {
#         "person_id": 405,
#         "id": 312,
#         "full_name": "Carmen Cardenas Uribe",
#         "rut": null,
#         "email": "carmenccu@hotmail.com",
#         "personal_email": "carmenccu@hotmail.com",
#         "address": "Jiron, Saenz Peña, 451",
#         "street": null,
#         "street_number": null,
#         "city": null,
#         "province": null,
#         "district": null,
#         "region": null,
#         "phone": "963754378",
#         "gender": "F",
#         "birthday": "1988-03-27",
#         "university": null,
#         "degree": null,
#         "bank": "BBVA Continental",
#         "account_type": "Cuenta de Ahorros",
#         "account_number": "001108140215772336",
#         "nationality": "Peruana",
#         "civil_status": "Casado",
#         "health_company": "es_salud",
#         "pension_regime": "afp",
#         "pension_fund": "prima",
#         "active_until": null,
#         "afc": null,
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2022-08-15",
#         "status": "activo",
#         "start_date": "2025-05-01",
#         "end_date": null,
#         "termination_reason": null,
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 322,
#         "rut_boss": null,
#         "base_wage": 8500,
#         "contract_type": "Contrato a Plazo Indeterminado",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "COORDINADOR COMERCIAL SABORES PE",
#         "area_id": 3,
#         "cost_center": "1201",
#         "ctrlit_recinto": null
#     },
#     {
#         "person_id": 490,
#         "id": 411,
#         "full_name": "Brenda Xiomara Chauca Juro",
#         "rut": null,
#         "email": "brendachaucajuro@gmail.com",
#         "personal_email": "brendachaucajuro@gmail.com",
#         "address": "RIO DE JANEIRO 109",
#         "street": null,
#         "street_number": null,
#         "city": null,
#         "province": null,
#         "district": null,
#         "region": null,
#         "phone": "930606441",
#         "gender": "F",
#         "birthday": "1997-02-08",
#         "university": null,
#         "degree": null,
#         "bank": "Banco de Crédito del Perú",
#         "account_type": "Cuenta de Ahorros",
#         "account_number": "00219310493263305616",
#         "nationality": "Peruana",
#         "civil_status": "Soltero",
#         "health_company": "es_salud",
#         "pension_regime": "afp",
#         "pension_fund": "profuturo",
#         "active_until": null,
#         "afc": null,
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2025-06-02",
#         "status": "activo",
#         "start_date": "2025-06-02",
#         "end_date": null,
#         "termination_reason": null,
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 327,
#         "rut_boss": null,
#         "base_wage": 2800,
#         "contract_type": "Contrato a Plazo Indeterminado",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "ASISTENTE ADMINISTRATIVO Y SERVICIO AL CLIENTE",
#         "area_id": 9,
#         "cost_center": "1151",
#         "ctrlit_recinto": null
#     },
#     {
#         "person_id": 406,
#         "id": 313,
#         "full_name": "Karen Chirinos Gomez",
#         "rut": null,
#         "email": "karen.chirinos.gomez@gmail.com",
#         "personal_email": "karen.chirinos.gomez@gmail.com",
#         "address": "Calle, Miguel Grau, MZ E LT 2, Urbanización Javier Heraud",
#         "street": null,
#         "street_number": null,
#         "city": null,
#         "province": null,
#         "district": null,
#         "region": null,
#         "phone": "940427575",
#         "gender": "F",
#         "birthday": "1983-10-16",
#         "university": null,
#         "degree": null,
#         "bank": "BBVA Continental",
#         "account_type": "Cuenta de Ahorros",
#         "account_number": "001103380200366318",
#         "nationality": "Peruana",
#         "civil_status": "Casado",
#         "health_company": "mapfre",
#         "pension_regime": "afp",
#         "pension_fund": "habitat",
#         "active_until": null,
#         "afc": null,
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2018-04-02",
#         "status": "activo",
#         "start_date": "2025-01-01",
#         "end_date": null,
#         "termination_reason": null,
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 326,
#         "rut_boss": null,
#         "base_wage": 10180,
#         "contract_type": "Contrato a Plazo Indeterminado",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "EJECUTIVO DE CUENTAS SENIOR",
#         "area_id": 3,
#         "cost_center": "1201",
#         "ctrlit_recinto": null
#     },
#     {
#         "person_id": 464,
#         "id": 371,
#         "full_name": "David Chuchon Rojas",
#         "rut": null,
#         "email": "nixca@gmail.com",
#         "personal_email": "nixca@gmail.com",
#         "address": "CPR VICTOR RAUL HAYA DE LA TORRE LT 10 LURIN",
#         "street": null,
#         "street_number": null,
#         "city": null,
#         "province": null,
#         "district": null,
#         "region": null,
#         "phone": "944044298",
#         "gender": "M",
#         "birthday": "2006-04-30",
#         "university": null,
#         "degree": null,
#         "bank": "BBVA Continental",
#         "account_type": "Cuenta de Ahorros",
#         "account_number": "01157900022189999605",
#         "nationality": "Peruana",
#         "civil_status": "Soltero",
#         "health_company": "es_salud",
#         "pension_regime": "afp",
#         "pension_fund": "integra",
#         "active_until": "2024-08-20",
#         "afc": null,
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2024-06-21",
#         "status": "inactivo",
#         "start_date": "2024-06-21",
#         "end_date": "2024-08-20",
#         "termination_reason": "terminacion_de_la_obra",
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 371,
#         "rut_boss": null,
#         "base_wage": 1250,
#         "contract_type": "Por necesidades de Mercado",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "AUXILIAR DE ALMACÉN",
#         "area_id": 7,
#         "cost_center": "1151",
#         "ctrlit_recinto": null
#     },
#     {
#         "person_id": 464,
#         "id": 382,
#         "full_name": "David Chuchon Rojas",
#         "rut": null,
#         "email": "nixca@gmail.com",
#         "personal_email": "nixca@gmail.com",
#         "address": "CPR VICTOR RAUL HAYA DE LA TORRE LT 10 LURIN",
#         "street": null,
#         "street_number": null,
#         "city": null,
#         "province": null,
#         "district": null,
#         "region": null,
#         "phone": "944044298",
#         "gender": "M",
#         "birthday": "2006-04-30",
#         "university": null,
#         "degree": null,
#         "bank": "BBVA Continental",
#         "account_type": "Cuenta de Ahorros",
#         "account_number": "01157900022189999605",
#         "nationality": "Peruana",
#         "civil_status": "Soltero",
#         "health_company": "es_salud",
#         "pension_regime": "afp",
#         "pension_fund": "integra",
#         "active_until": null,
#         "afc": null,
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2024-11-21",
#         "status": "activo",
#         "start_date": "2025-09-01",
#         "end_date": null,
#         "termination_reason": null,
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 366,
#         "rut_boss": null,
#         "base_wage": 1250,
#         "contract_type": "Por necesidades de Mercado",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "AUXILIAR DE ALMACÉN",
#         "area_id": 7,
#         "cost_center": "1151",
#         "ctrlit_recinto": null
#     },
#     {
#         "person_id": 407,
#         "id": 314,
#         "full_name": "Marcos Chuchón Rojas",
#         "rut": null,
#         "email": "rojasmaroc@gmail.com",
#         "personal_email": "rojasmaroc@gmail.com",
#         "address": "Pasaje 2000, Santa Ana de Lurín, Lote 10",
#         "street": null,
#         "street_number": null,
#         "city": null,
#         "province": null,
#         "district": null,
#         "region": null,
#         "phone": "902170616",
#         "gender": "M",
#         "birthday": "1999-09-22",
#         "university": null,
#         "degree": null,
#         "bank": "BBVA Continental",
#         "account_type": "Cuenta de Ahorros",
#         "account_number": "001109330200602822",
#         "nationality": "Peruana",
#         "civil_status": "Soltero",
#         "health_company": "es_salud",
#         "pension_regime": "afp",
#         "pension_fund": "prima",
#         "active_until": null,
#         "afc": null,
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2021-07-06",
#         "status": "activo",
#         "start_date": "2025-08-01",
#         "end_date": null,
#         "termination_reason": null,
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 366,
#         "rut_boss": null,
#         "base_wage": 1830,
#         "contract_type": "Contrato a Plazo Indeterminado",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "ASISTENTE DOCUMENTARIO",
#         "area_id": 7,
#         "cost_center": "1151",
#         "ctrlit_recinto": null
#     },
#     {
#         "person_id": 458,
#         "id": 365,
#         "full_name": "Yohanna Antonia Copacondori Puma",
#         "rut": null,
#         "email": "covertsecret09@gmail.com",
#         "personal_email": "covertsecret09@gmail.com",
#         "address": "LIMA",
#         "street": null,
#         "street_number": null,
#         "city": null,
#         "province": null,
#         "district": null,
#         "region": null,
#         "phone": "998474932",
#         "gender": "F",
#         "birthday": "2001-03-09",
#         "university": null,
#         "degree": null,
#         "bank": "Banco de Crédito del Perú",
#         "account_type": "Cuenta de Ahorros",
#         "account_number": "00219110076791406953",
#         "nationality": "Peruana",
#         "civil_status": "Soltero",
#         "health_company": "es_salud",
#         "pension_regime": "afp",
#         "pension_fund": "integra",
#         "active_until": "2025-08-15",
#         "afc": null,
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2024-03-05",
#         "status": "inactivo",
#         "start_date": "2025-01-01",
#         "end_date": "2025-08-15",
#         "termination_reason": "renuncia",
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 339,
#         "rut_boss": null,
#         "base_wage": 1550,
#         "contract_type": "Contrato a Plazo Indeterminado",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "ASISTENTE DE MUESTRAS",
#         "area_id": 17,
#         "cost_center": "1201",
#         "ctrlit_recinto": null
#     },
#     {
#         "person_id": 408,
#         "id": 315,
#         "full_name": "Celso Miguel Cordova Pasiche",
#         "rut": null,
#         "email": null,
#         "personal_email": null,
#         "address": "Av. Julio C. Tello # 184 - Callao",
#         "street": null,
#         "street_number": null,
#         "city": null,
#         "province": null,
#         "district": null,
#         "region": null,
#         "phone": "",
#         "gender": "M",
#         "birthday": "1988-03-23",
#         "university": null,
#         "degree": null,
#         "bank": "BBVA Continental",
#         "account_type": "Cuenta de Ahorros",
#         "account_number": "001108730200078184",
#         "nationality": "Peruana",
#         "civil_status": "Casado",
#         "health_company": "es_salud",
#         "pension_regime": "afp",
#         "pension_fund": "integra",
#         "active_until": "2024-06-19",
#         "afc": null,
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2015-11-11",
#         "status": "inactivo",
#         "start_date": "2024-01-01",
#         "end_date": "2024-06-19",
#         "termination_reason": "mutuo_disenso",
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 309,
#         "rut_boss": null,
#         "base_wage": 2510,
#         "contract_type": "Contrato a Plazo Indeterminado",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "ASISTENTE ADMINISTRATIVO ALMACEN",
#         "area_id": 7,
#         "cost_center": "1151",
#         "ctrlit_recinto": null
#     },
#     {
#         "person_id": 408,
#         "id": 395,
#         "full_name": "Celso Miguel Cordova Pasiche",
#         "rut": null,
#         "email": null,
#         "personal_email": null,
#         "address": "Av. Julio C. Tello # 184 - Callao",
#         "street": null,
#         "street_number": null,
#         "city": null,
#         "province": null,
#         "district": null,
#         "region": null,
#         "phone": "",
#         "gender": "M",
#         "birthday": "1988-03-23",
#         "university": null,
#         "degree": null,
#         "bank": "BBVA Continental",
#         "account_type": "Cuenta de Ahorros",
#         "account_number": "001108730200078184",
#         "nationality": "Peruana",
#         "civil_status": "Casado",
#         "health_company": "es_salud",
#         "pension_regime": "afp",
#         "pension_fund": "integra",
#         "active_until": "2025-03-01",
#         "afc": null,
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2025-03-01",
#         "status": "inactivo",
#         "start_date": "2025-03-01",
#         "end_date": "2025-03-01",
#         "termination_reason": "renuncia",
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 309,
#         "rut_boss": null,
#         "base_wage": 2510,
#         "contract_type": "Contrato a Plazo Indeterminado",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "ASISTENTE ADMINISTRATIVO ALMACEN",
#         "area_id": 7,
#         "cost_center": "1151",
#         "ctrlit_recinto": null
#     },
#     {
#         "person_id": 409,
#         "id": 316,
#         "full_name": "Patricia Alejandra Cordova Valdivia",
#         "rut": null,
#         "email": "patricia.cordovaldivia@gmail.com",
#         "personal_email": "patricia.cordovaldivia@gmail.com",
#         "address": "Prolongación, Paseo de la República, 6921, torre 1, Dpto 302",
#         "street": null,
#         "street_number": null,
#         "city": null,
#         "province": null,
#         "district": null,
#         "region": null,
#         "phone": "983770898",
#         "gender": "F",
#         "birthday": "1987-07-05",
#         "university": null,
#         "degree": null,
#         "bank": "BBVA Continental",
#         "account_type": "Cuenta de Ahorros",
#         "account_number": "001108720200013532",
#         "nationality": "Peruana",
#         "civil_status": "Casado",
#         "health_company": "mapfre",
#         "pension_regime": "afp",
#         "pension_fund": "prima",
#         "active_until": null,
#         "afc": null,
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2015-06-08",
#         "status": "activo",
#         "start_date": "2025-01-01",
#         "end_date": null,
#         "termination_reason": null,
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 326,
#         "rut_boss": null,
#         "base_wage": 17100,
#         "contract_type": "Contrato a Plazo Indeterminado",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "KEY ACCOUNT MANAGER",
#         "area_id": 3,
#         "cost_center": "1201",
#         "ctrlit_recinto": null
#     },
#     {
#         "person_id": 410,
#         "id": 317,
#         "full_name": "Jhair Manuel Cuya Curo",
#         "rut": null,
#         "email": "jhaircuya95@gmail.com",
#         "personal_email": "jhaircuya95@gmail.com",
#         "address": "Jirón, Huascar Manzana 16, Lote 1, Km 40",
#         "street": null,
#         "street_number": null,
#         "city": null,
#         "province": null,
#         "district": null,
#         "region": null,
#         "phone": "931964908",
#         "gender": "M",
#         "birthday": "1995-08-19",
#         "university": null,
#         "degree": null,
#         "bank": "BBVA Continental",
#         "account_type": "Cuenta de Ahorros",
#         "account_number": "001109330200521709",
#         "nationality": "Peruana",
#         "civil_status": "Soltero",
#         "health_company": "es_salud",
#         "pension_regime": "afp",
#         "pension_fund": "integra",
#         "active_until": null,
#         "afc": null,
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2020-03-09",
#         "status": "activo",
#         "start_date": "2025-01-01",
#         "end_date": null,
#         "termination_reason": null,
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 366,
#         "rut_boss": null,
#         "base_wage": 1710,
#         "contract_type": "Contrato a Plazo Indeterminado",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "AUXILIAR DE ALMACÉN",
#         "area_id": 7,
#         "cost_center": "1151",
#         "ctrlit_recinto": null
#     },
#     {
#         "person_id": 498,
#         "id": 418,
#         "full_name": "Jesus Martin De La Cruz Uchuya",
#         "rut": null,
#         "email": "jdcu061993@gmail.com",
#         "personal_email": "jdcu061993@gmail.com",
#         "address": "AV.CARLOS ALVAREZ MZ C LOATE 6 SECTOR 18",
#         "street": null,
#         "street_number": null,
#         "city": null,
#         "province": null,
#         "district": null,
#         "region": null,
#         "phone": "984677898",
#         "gender": "M",
#         "birthday": "1993-04-06",
#         "university": null,
#         "degree": null,
#         "bank": "Scotiabank",
#         "account_type": "Cuenta de Ahorros",
#         "account_number": "00972420833057468360",
#         "nationality": "Peruana",
#         "civil_status": "Conviviente",
#         "health_company": "es_salud",
#         "pension_regime": "afp",
#         "pension_fund": "integra",
#         "active_until": null,
#         "afc": null,
#         "retired": false,
#         "retirement_regime": null,
#         "active_since": "2025-09-01",
#         "status": "activo",
#         "start_date": "2025-09-01",
#         "end_date": null,
#         "termination_reason": null,
#         "payment_method": "Transferencia Bancaria",
#         "id_boss": 366,
#         "rut_boss": null,
#         "base_wage": 1300,
#         "contract_type": "Inicio o incremento de nueva actividad",
#         "contract_finishing_date_1": null,
#         "contract_finishing_date_2": null,
#         "name_role": "AUXILIAR DE ALMACÉN",
#         "area_id": 7,
#         "cost_center": "1151",
#         "ctrlit_recinto": null
#     }
# ]
